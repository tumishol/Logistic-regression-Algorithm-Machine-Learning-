# %%
import pandas as pd

df = pd.read_csv('E:\Datasets\CarPrice_Assignment.csv')

# %%
pd.set_option('display.max.columns',None)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
df1 = df[['enginesize','horsepower','price']]

# %%
df1.head()
# Out:
#    enginesize  horsepower    price
# 0         130         111  13495.0
# 1         130         111  16500.0
# 2         152         154  16500.0
# 3         109         102  13950.0
# 4         136         115  17450.0

# %%
#setting up x & y variables

X = df1[['enginesize','horsepower']]
y = df1['price']

# %%
X.shape
# Out:
# (205, 2)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree = 2)
X_poly = poly.fit_transform(X)

Lr = LinearRegression()

model = Lr.fit(X_poly,y)

# %%
X_poly.shape
# Out:
# (205, 6)

# %%
coefficient=model.coef_
coefficient
# Out:
# array([  0.        ,  86.53105841, 135.73859123,   0.83187643,
#         -1.70108368,   0.64794251])

# %%
intercept = model.intercept_
intercept
# Out:
# -9968.850222325422

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

Input = [('scale',StandardScaler()),('polynomial',PolynomialFeatures(include_bias = False)),('model',LinearRegression())]

# %%
pipe = Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
pipe.fit(X_poly,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe = pipe.predict(X_poly)
ypipe[0:5]
# Out:
# array([12792.8127919 , 12792.8127919 , 17315.38789099, 11112.17426934,
#        13496.39555359])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.subplots(figsize=(7,7))

ax1 = sns.distplot(y, hist=False, color = 'r',label ='Actual')
sns.distplot(ypipe, hist=False,color = 'b', label ='Predicted', ax = ax1)
plt.title('Price v Variables')
plt.xlabel('Price')
plt.ylabel('Car proportions')
plt.legend()
plt.show()
# Out:
# c:\users\ncmol\appdata\local\programs\common\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\users\ncmol\appdata\local\programs\common\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
Lr.score(X_poly,ypipe)
# Out:
# 0.9437069192618119

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y,ypipe)
print(MSE)
# Out:
# 9031084.675380768
